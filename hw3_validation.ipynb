# %% [markdown]
# # Homework 3
#
# You will have 2 datasets to work on.
# #### You have to answer questions in this [form](https://goo.gl/forms/5gfxvKZxpoydoeOB2) and provide your code
#
# ### 1. Wikipedia Web Traffic Time Series
#
# Data from [Kaggle competition](https://www.kaggle.com/c/web-traffic-time-series-forecasting)* )
#
# *wikipedia_train3* - train data *wikipedia_test3* - test data created by us from original train data . For more information about dataset, please visit Homework1 assignment
#
#
# ### 2. French dataset
#
# Target variable is prime_tot_ttc – house of insurance price.<p>
# The variables in the files are:<p>
# code_postal: postal code of the insured property<p>
# nb_pieces: number of rooms<p>
# veranda: presence of a veranda<p>
# biens_nomades: ceiling of coverage of goods (laptop, tablets, musical instruments ,…)<p>
# sit_fam: family situation of the insured<p>
# profession: profession of the insured<p>
# nature_lri: nature of the insured property<p>
# societe: company covering the risk<p>
# cdomact: area of activity of the insured<p>
# niv_urbanisation: level of urbanization in which is the insured property<p>
# age_societaire: age of the member<p>
# objets_precieux: presence of precious objects in the insured property<p>
# pres_contrat_auto: holding a contract of auto insurance<p>
# formule: guarantee formula<p>
# sit_juridique: legal situation<p>
# surf_habitat: area of insured property<p>
# patrimoine_mob: amount of heritage insured furniture<p>
# var1 - ... - var11: non-explicit variables<p>

# %% [markdown]
# ## Wikipedia page views (SMAPE metric)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import datetime

# %%
### This is data from wikipedia3 archive in data folder

train = pd.read_csv("../data/wikipedia_train3.csv")
test = pd.read_csv("../data/wikipedia_test3.csv")
test['date'] = test['date'].astype('datetime64[ns]')
train['date'] = train['date'].astype('datetime64[ns]')

# %%
test['date'].min(), test['date'].max(), train['date'].min(), train['date'].max()
# Out:
# (Timestamp('2016-09-10 00:00:00'),
#  Timestamp('2016-11-10 00:00:00'),
#  Timestamp('2016-01-01 00:00:00'),
#  Timestamp('2016-08-31 00:00:00'))

# %% [markdown]
# **1.** Take a look carefuly at train and test dataset. Note for you what is the difference in them and how they are dependent. **For _only_ train** create a holdout validation using any type of split you think is useful here. What is the split type you are using? Answer in google forms
#
# **2.** Write a code to compare the score of your validation and test set. For scoring, use metric SMAPE (code is in lecture). For prediction use 15 previous days median. In the google form write your validation score.

# %%
test_delta = test['date'].max() - test['date'].min() # 61 days
train_delta = train['date'].max() - train['date'].min() # 243 days

# %%
sep = train_delta*0.3
separizer = train['date'].max() - sep # Timestamp('2016-06-19 02:24:00')

# %%
_train, _test = train[train['date']<separizer], train[train['date']>=separizer]

# %%
(_train.count()+_test.count()) == train.count()
# Out:
# Page      True
# date      True
# Visits    True
# dtype: bool

# %%
train
# Out:
#                                                       Page       date  \
# 0        Special:Search_zh.wikipedia.org_all-access_spider 2016-01-01
# 1          Wikipedia:首页_zh.wikipedia.org_all-access_spider 2016-01-01
# 2            Project:上传_zh.wikipedia.org_all-access_spider 2016-01-01
# 3          Special:用户登录_zh.wikipedia.org_all-access_spider 2016-01-01
# 4        Championnat_d'Europe_de_football_2016_fr.wikip... 2016-01-01
# 5        Cristiano_Ronaldo_fr.wikipedia.org_desktop_all... 2016-01-01
# 6             Facebook_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 7        Liste_d'attentats_meurtriers_fr.wikipedia.org_... 2016-01-01
# 8        Liste_des_automobiles_Ferrari_fr.wikipedia.org... 2016-01-01
# 9        Prince_(musicien)_fr.wikipedia.org_desktop_all... 2016-01-01
# 10       Special:Search_fr.wikipedia.org_desktop_all-ag... 2016-01-01
# 11       Utilisateur:0x010C/script/PopupVandalism.js/bo... 2016-01-01
# 12         Victor_Hugo_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 13                Wiki_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 14            load.php_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 15             Accueil_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 16       Association_sportive_de_Monaco_football_club_f... 2016-01-01
# 17           Astrolabe_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 18         David_Bowie_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 19        Donald_Trump_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 20        Fichier_.PAC_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 21              France_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 22       Game_of_Thrones_fr.wikipedia.org_desktop_all-a... 2016-01-01
# 23              Google_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 24       Joker_(comics)_fr.wikipedia.org_desktop_all-ag... 2016-01-01
# 25               Paris_fr.wikipedia.org_desktop_all-agents 2016-01-01
# 26       Portail:Accueil_fr.wikipedia.org_desktop_all-a... 2016-01-01
# 27       Sp?cial:Search_fr.wikipedia.org_desktop_all-ag... 2016-01-01
# 28       Typologie_des_routes_pour_leur_conception_en_F... 2016-01-01
# 29       Christiane_Taubira_fr.wikipedia.org_desktop_al... 2016-01-01
# ...                                                    ...        ...
# 2882830  Liste_der_Präsidenten_der_Vereinigten_Staaten_... 2016-08-31
# 2882831  Grey’s_Anatomy_de.wikipedia.org_all-access_all... 2016-08-31
# 2882832  Jérôme_Boateng_de.wikipedia.org_all-access_all... 2016-08-31
# 2882833  Menderes_Bağcı_de.wikipedia.org_all-access_all... 2016-08-31
# 2882834  Pfeiffer-Drüsenfieber_de.wikipedia.org_all-acc... 2016-08-31
# 2882835  Konfektionsgröße_de.wikipedia.org_all-access_a... 2016-08-31
# 2882836    Rumänien_de.wikipedia.org_all-access_all-agents 2016-08-31
# 2882837  Vereinigtes_Königreich_de.wikipedia.org_all-ac... 2016-08-31
# 2882838  Spezial:Letzte_Änderungen_de.wikipedia.org_all... 2016-08-31
# 2882839  Die_Bestimmung_–_Divergent_de.wikipedia.org_al... 2016-08-31
# 2882840      Türkei_de.wikipedia.org_all-access_all-agents 2016-08-31
# 2882841  Mario_Gómez_de.wikipedia.org_all-access_all-ag... 2016-08-31
# 2882842  Bundespräsident_(Deutschland)_de.wikipedia.org... 2016-08-31
# 2882843  Deutsche_Fußballnationalmannschaft_de.wikipedi... 2016-08-31
# 2882844  Bipolare_Störung_de.wikipedia.org_all-access_a... 2016-08-31
# 2882845  Jan_Böhmermann_de.wikipedia.org_all-access_all... 2016-08-31
# 2882846  Österreich_de.wikipedia.org_all-access_all-agents 2016-08-31
# 2882847  Fußball-Weltmeisterschaft_de.wikipedia.org_all... 2016-08-31
# 2882848  Borderline-Persönlichkeitsstörung_de.wikipedia... 2016-08-31
# 2882849  Götz_George_de.wikipedia.org_all-access_all-ag... 2016-08-31
# 2882850  Adele_(Sängerin)_de.wikipedia.org_all-access_a... 2016-08-31
# 2882851  Liste_der_Länder_Europas_de.wikipedia.org_all-... 2016-08-31
# 2882852  Fußball-Europameisterschaft_2012_de.wikipedia.... 2016-08-31
# 2882853  Joachim_Löw_de.wikipedia.org_all-access_all-ag... 2016-08-31
# 2882854        Köln_de.wikipedia.org_all-access_all-agents 2016-08-31
# 2882855  The_Revenant_–_Der_Rückkehrer_de.wikipedia.org... 2016-08-31
# 2882856  Especial:Entrar_es.wikipedia.org_all-access_sp... 2016-08-31
# 2882857  Especial:Libro_es.wikipedia.org_all-access_spider 2016-08-31
# 2882858  Special:Search_es.wikipedia.org_all-access_spider 2016-08-31
# 2882859  Wikipedia:Portada_es.wikipedia.org_all-access_... 2016-08-31
#
#            Visits
# 0          2660.0
# 1          9936.0
# 2          1712.0
# 3          3175.0
# 4          1682.0
# 5          1762.0
# 6          2261.0
# 7           379.0
# 8            96.0
# 9           300.0
# 10         6577.0
# 11         2166.0
# 12         2004.0
# 13         1758.0
# 14            0.0
# 15         6795.0
# 16         1202.0
# 17           77.0
# 18          737.0
# 19          875.0
# 20         6213.0
# 21         3872.0
# 22         2553.0
# 23         1544.0
# 24          255.0
# 25         6502.0
# 26         2304.0
# 27       130753.0
# 28            3.0
# 29          611.0
# ...           ...
# 2882830    1841.0
# 2882831    2931.0
# 2882832    2435.0
# 2882833     582.0
# 2882834    2117.0
# 2882835    3369.0
# 2882836    2197.0
# 2882837    3247.0
# 2882838   13678.0
# 2882839    1859.0
# 2882840    3312.0
# 2882841    1388.0
# 2882842    2514.0
# 2882843    7080.0
# 2882844    2857.0
# 2882845    1689.0
# 2882846    4958.0
# 2882847    2727.0
# 2882848    2689.0
# 2882849     785.0
# 2882850     980.0
# 2882851    2854.0
# 2882852     338.0
# 2882853    3271.0
# 2882854    2688.0
# 2882855     942.0
# 2882856    1193.0
# 2882857    1862.0
# 2882858    7217.0
# 2882859   57752.0
#
# [2882860 rows x 3 columns]

# %%
def pandas_smape(df):
    df.fillna(0, inplace=True)
    df["SMAPE"] = 200 * np.abs(df["Visits"] - df["pred_Visits"]) / (df["Visits"] + df["pred_Visits"])
    df["SMAPE"].fillna(0, inplace=True)
    return np.mean(df["SMAPE"])

# %%
from dateutil.relativedelta import relativedelta
def create_validation(df, start_date):
    return df[(df['date'] >= pd.to_datetime(start_date) - relativedelta(month=2)) & \
              (df['date'] <  pd.to_datetime(start_date) - relativedelta(days=15))].index, \
           df[(df['date'] >= pd.to_datetime(start_date) - relativedelta(days=0)) & \
              (df['date'] <  pd.to_datetime(start_date) + relativedelta(days=30))].index

# %%
CVIterator = []
arr = ['2016-03-10', '2016-04-10', '2016-05-10', '2016-06-10', '2016-07-10', '2016-08-01']
for date in arr:
    CVIterator.append(create_validation(train, date))

# %%
def last_15_days_pred(train_df, val_df):
    train_df = train_df.loc[train_df['date'] > (train_df['date'].max() - relativedelta(days=15))].copy()
    train_df.drop('date', axis=1, inplace=True)
    median_baseline = train_df.groupby(['Page']).median().reset_index()
    median_baseline.rename(columns={"Visits": "pred_Visits"}, inplace=True)
    return val_df.merge(median_baseline, on="Page", how='left')

# %%
test_smape(last_15_days_pred)
# Out:
# 40.007012702044264

# %%
def validate_smape(CVIterator, df_predictor):
    scores = []
    for train_indexes, val_indexes in CVIterator:
        val_df_with_pred = df_predictor(train.iloc[train_indexes].copy(), 
                                        train.iloc[val_indexes].copy())
        score = pandas_smape(val_df_with_pred)
        scores.append(score)
    return scores, np.mean(scores)

# %%
def test_smape(df_predictor):
    test_df_with_pred = df_predictor(train.copy(), 
                                     test.copy())
    return pandas_smape(test_df_with_pred)

# %%
validate_smape(CVIterator, last_15_days_pred)
# Out:
# ([42.44889941423534,
#   41.085033170305515,
#   38.49899335332539,
#   44.61995852761694,
#   43.46571317164605,
#   40.075843377320304],
#  41.699073502408254)

# %%
test.head()
# Out:
#                                                 Page       date  Visits
# 0  Special:Search_zh.wikipedia.org_all-access_spider 2016-09-10   640.0
# 1    Wikipedia:首页_zh.wikipedia.org_all-access_spider 2016-09-10  5609.0
# 2      Project:上传_zh.wikipedia.org_all-access_spider 2016-09-10  3121.0
# 3    Special:用户登录_zh.wikipedia.org_all-access_spider 2016-09-10   362.0
# 4  Championnat_d'Europe_de_football_2016_fr.wikip... 2016-09-10   533.0

# %%
### Your code here

# %% [markdown]
# **3.** Perform K-fold validation using your type of split. Run GridSearch with any classificator you like and set of parameters to optimize, providing it with your custom validation.  Compare the score of your validation and test set. For scoring, again, use metrics SMAPE. In the google form write your scores on validation and test sets

# %%
### Your code here
def create_validation(df, start_date):
    pass

# %%
params = dict(classifier__C=[0.1, 0.01, 0.001, 0.0001])
grid_search = GridSearchCV(pipeline, param_grid=params, cv=3)

# %%
### Your validation iterator
CVIterator = []

# %% [markdown]
# ## French house insurance prediction (MAPE metric)

# %% [markdown]
# **1.** Take a look carefuly at train and test dataset. Note for you what is the difference in them and how they are dependent. You may use any tool you like, any EDA you want. Decribe your validation and reason for your choice in google form.
#
# **2.**
# + Implement your validation.
# + Generate additional features.
# + Build a model you like/you can.
# + Wait for training your model. If it takes too much time, listen to https://www.youtube.com/watch?v=XWkGL4eZR3E
# + Submit your scores on validation and test to google form. Use MAPE metric for scoring.
# + Ланфрен ланфра лантатита

# %%
train = pd.read_csv('../data/train_french.csv')
test = pd.read_csv('../data/test_french.csv')
from catboost import CatBoostRegressor
import pandas_profiling as pp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-333-86bf41838c77> in <module>()
#       1 train = pd.read_csv('../data/train_french.csv')
#       2 test = pd.read_csv('../data/test_french.csv')
# ----> 3 from catboost import CatBoostRegressor
#       4 import pandas_profiling as pp
#
# ModuleNotFoundError: No module named 'catboost'

# %%
#pp.ProfileReport(train)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-0.6.3-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (24.5MB)
#     100% |████████████████████████████████| 24.5MB 42kB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/site-packages (from catboost)
# Requirement already satisfied: six in /usr/local/lib/python2.7/site-packages (from catboost)
# Installing collected packages: catboost
# Successfully installed catboost-0.6.3
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
train.head()
# Out:
#    code_postal  nb_pieces veranda  biens_nomades     sit_fam  \
# 0        62510          1     NON            500  Indivividu
# 1        83126          2     NON            500  Indivividu
# 2        68224          3     NON            500  Indivividu
# 3        30263          3     NON            500     Famille
# 4        72231          2     NON            500     Famille
#
#                          profession        nature_lri  societe  \
# 0                    agent; employe  Sans information        2
# 1                  cadre; ingenieur  Sans information        2
# 2  enseignant; formateur; chercheur            Maison        1
# 3                    agent; employe            Maison        2
# 4    educateur; animateur; moniteur       Appartement        1
#
#    domaine_activite niv_urbanisation      ...        var3  var4  var5  var6  \
# 0                34                A      ...           0   194    49     0
# 1                37                A      ...           0     0   100     0
# 2                 1                E      ...           1    98   100     0
# 3                34                A      ...           0   151    38     0
# 4                19                D      ...           0    39   100     0
#
#    var7  var8  var9  var10  var11  prime_tot_ttc
# 0     0     1   NON     30      2          67.68
# 1     0     5   NON     12      1         120.60
# 2     0     5   NON     30      2         100.62
# 3     0     1   NON     15      1          58.73
# 4     0     1   NON      0      2         132.65
#
# [5 rows x 29 columns]

# %%
test.head()
# Out:
#    code_postal  nb_pieces veranda  biens_nomades     sit_fam  \
# 0         6029          5     OUI            500     Famille
# 1        62128          2     NON              0     Famille
# 2        81065          4     NON           1000  Indivividu
# 3         5023          3     NON            500  Indivividu
# 4        62178          2     NON            500     Famille
#
#                          profession        nature_lri  societe  \
# 0                    agent; employe            Maison        1
# 1  enseignant; formateur; chercheur       Appartement        1
# 2           homme ou femme au foyer  Sans information        2
# 3                    agent; employe            Maison        2
# 4  enseignant; formateur; chercheur       Appartement        1
#
#    domaine_activite niv_urbanisation      ...        var3  var4  var5  var6  \
# 0                 7                C      ...           0   164    41     0
# 1                 1                D      ...           1    85   100     0
# 2                99                ~      ...           0    94   100     0
# 3                38                C      ...           0   101   100     0
# 4                 1                ~      ...           1   125   100     1
#
#    var7  var8  var9  var10  var11  prime_tot_ttc
# 0     0     1   NON     30      1         107.94
# 1     0     1   NON     30      2          80.41
# 2     0     1   NON     30      2         142.12
# 3     0     5   NON     30      2          76.55
# 4     0     1   NON      0      2         150.45
#
# [5 rows x 29 columns]

# %%
def mape_score(y_true, y_pred):
    return np.sum(100. / y_true.shape[0] * np.abs((y_true - y_pred) / y_true))

# %%
x_train, x_val, y_train, y_val = train_test_split(train.drop('prime_tot_ttc', axis=1), 
                                                   train['prime_tot_ttc'],
                                                   test_size=0.01, 
                                                   random_state=42)
